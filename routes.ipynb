# %% [markdown]
# # Chargement et nettoyage

# %% [markdown]
# Importation du fichier csv des routes et ajout en dataframe

# %%
import pandas as pd
filePath = ('C:\\Users\\Aloïs\\workspace\\datacg.csv')
dfroutes = pd.read_csv(filePath,sep=";",decimal=",")
dfroutes
# Out:
#                                   entityid        route  rub  age  mois  \
# 0     000efbb3-e7c1-4b9c-a54e-1e0d6d81988a     76 D0131   20    0     7
# 1     0011b2a4-5a64-4223-a856-6c9e8b6b2b48     76 D0293   20    0     7
# 2     0011d99f-9091-4be4-a16c-354f23b24004     76 D0003   20    0     7
# 3     00155332-804f-4547-8537-0897d7e479e1     76 D0915   20    0    11
# 4     0016e2d9-78bb-4092-b846-90452703009a     76 D0022   20    0     7
# 5     003419aa-3c96-48f8-beb9-8f4eddcb857c   76 E0418D2   20    0     1
# 6     003587bb-5f73-4991-99b4-e735899b9736     76 D0109   20    0     7
# 7     0057d94b-d85e-4d81-97c6-0cf180f12ad5     76 D0016   20    0     7
# 8     005e178b-2c97-4bb7-9e7a-c8ae2295d4e1     76 D0925   20    0     7
# 9     00606c44-4388-4b0b-a406-b87c2e5aa63e     76 D0481   20    0     7
# 10    00607ef4-0cc4-401f-a420-687518fa6545     76 D0108   20    0     7
# 11    00646094-cabd-4c34-a713-2ecad5e79730     76 D0921   20    0     7
# ...

# %% [markdown]
# Vérification du type de valeur de la colonne 'epaisseurdernierstravaux'

# %%
isinstance(dfroutes.loc[0,'epaisseurdernierstravaux'],float)
# Out:
# True

# %% [markdown]
# Suppression des lignes contenant la valeur 9999.99 dans la colonne 'epaisseurdernierstravaux', valeur non pertinente pour une étude de la data dans ce fichier

# %%
dfroutes = dfroutes[dfroutes.epaisseurdernierstravaux != 9999.99]
dfroutes
# Out:
#                                   entityid        route  rub  age  mois  \
# 0     000efbb3-e7c1-4b9c-a54e-1e0d6d81988a     76 D0131   20    0     7
# 1     0011b2a4-5a64-4223-a856-6c9e8b6b2b48     76 D0293   20    0     7
# 2     0011d99f-9091-4be4-a16c-354f23b24004     76 D0003   20    0     7
# 3     00155332-804f-4547-8537-0897d7e479e1     76 D0915   20    0    11
# 4     0016e2d9-78bb-4092-b846-90452703009a     76 D0022   20    0     7
# 5     003419aa-3c96-48f8-beb9-8f4eddcb857c   76 E0418D2   20    0     1
# 6     003587bb-5f73-4991-99b4-e735899b9736     76 D0109   20    0     7
# 7     0057d94b-d85e-4d81-97c6-0cf180f12ad5     76 D0016   20    0     7
# 8     005e178b-2c97-4bb7-9e7a-c8ae2295d4e1     76 D0925   20    0     7
# 9     00606c44-4388-4b0b-a406-b87c2e5aa63e     76 D0481   20    0     7
# 10    00607ef4-0cc4-401f-a420-687518fa6545     76 D0108   20    0     7
# 11    00646094-cabd-4c34-a713-2ecad5e79730     76 D0921   20    0     7
# ...

# %% [markdown]
# Suppression de la colonne 'age' qui est inutile ...

# %%
dfroutes = dfroutes.drop(['age'], axis = 1)
dfroutes
# Out:
#                                   entityid        route  rub  mois  annee  \
# 0     000efbb3-e7c1-4b9c-a54e-1e0d6d81988a     76 D0131   20     7      7
# 1     0011b2a4-5a64-4223-a856-6c9e8b6b2b48     76 D0293   20     7      7
# 2     0011d99f-9091-4be4-a16c-354f23b24004     76 D0003   20     7      7
# 3     00155332-804f-4547-8537-0897d7e479e1     76 D0915   20    11      9
# 4     0016e2d9-78bb-4092-b846-90452703009a     76 D0022   20     7      7
# 5     003419aa-3c96-48f8-beb9-8f4eddcb857c   76 E0418D2   20     1     10
# 6     003587bb-5f73-4991-99b4-e735899b9736     76 D0109   20     7      7
# 7     0057d94b-d85e-4d81-97c6-0cf180f12ad5     76 D0016   20     7      7
# 8     005e178b-2c97-4bb7-9e7a-c8ae2295d4e1     76 D0925   20     7     11
# 9     00606c44-4388-4b0b-a406-b87c2e5aa63e     76 D0481   20     7      7
# 10    00607ef4-0cc4-401f-a420-687518fa6545     76 D0108   20     7      7
# 11    00646094-cabd-4c34-a713-2ecad5e79730     76 D0921   20     7      7
# ...

# %% [markdown]
# # Analyse
#
# Les 5 natures de travaux les plus fréquentes :

# %%
    print(dfroutes.naturedernierstravaux.value_counts()[:5])
analyse = dfroutes.naturedernierstravaux.value_counts()[:5]
# Out:
# BB      1189
# COUL     994
# ES       864
# BBUM     348
# BBTM     340
# Name: naturedernierstravaux, dtype: int64

# %% [markdown]
# Nombre de travaux réalisés et l'épaisseur moyenne en fonction de l'année :

# %%
#Il manque 'epaisseurdernierstravaux' pour le moment
print(dfroutes.naturedernierstravaux.groupby(dfroutes.anneedernierstravaux).value_counts())
analyse2 = dfroutes.naturedernierstravaux.groupby(dfroutes.anneedernierstravaux).value_counts()
# Out:
# anneedernierstravaux  naturedernierstravaux
# 1900                  BB                        4
# 1945                  PAVES                     2
# 1950                  I                         1
# 1952                  PAVES                     2
# 1974                  BBSG                      1
# 1975                  BBSG                      2
#                       BB                        1
# 1977                  BBMP                      1
# 1980                  ES                        1
# 1981                  BBSG                      6
#                       ES                        2
#                       BBAUT                     1
#                       BBMP                      1
# 1982                  BBSGP                     2
# 1983                  BB                        3
#                       ES                        3
#                       PAVES                     2
#                       BBMP                      1
# ...

# %% [markdown]
# # Analyse graphique
#
# Pour la nature des travaux :

# %%
import numpy as np
import matplotlib.pyplot as plt

n, bins, patches = plt.hist(analyse)

plt.title('Histogramme Nature des travaux')
plt.grid(True)
plt.show()

plt.pie(analyse)
plt.show()

# %% [markdown]
# Nombre et épaisseur moyennes de travaux :

# %%
n, bins, patches = plt.hist(analyse2)

plt.title('Nbr et épaisseur de travaux')
plt.grid(True)
plt.show()

plt.pie(analyse2)
plt.show()
