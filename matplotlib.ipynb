# %% [markdown]
# %matplotlib inline

# %% [markdown]
# # Pyplot tutorial
#
# matplotlib.pyplot est une collection de fonctions de commande de style qui rendent le travail de matplotlib comme MATLAB. Chaque pyplot fonction permet un changement à un chiffre: par exemple, crée un personnage, crée une zone de traçage dans une figure, parcelles quelques lignes dans une zone de traçage, orne le terrain avec des étiquettes, etc. Dans matplotlib.pyplot différents états sont conservés dans la fonction appels, de sorte qu'il conserve la trace des choses comme le chiffre actuel et de la zone de traçage, et les fonctions de traçage sont dirigés vers les axes actuels (s'il vous plaît noter que les «axes» ici et dans la plupart des endroits dans la documentation se réfère aux axes partie d'une figure Et non le terme mathématique strict pour plus d'un axe).

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# Vous vous demandez peut-être pourquoi l'axe des x varie de 0 à 3 et l'axe des y de 1 à 4. Si vous fournissez une seule liste ou un tableau à la plot() commande, matplotlib suppose qu'il est une séquence de valeurs y, et génère les valeurs de x pour vous automatiquement. Depuis les plages de python commencent avec 0, la valeur par défaut x vecteur a la même longueur que y , mais commence par 0. Par conséquent , les données de x sont [0,1,2,3].
#
# plot() est une commande polyvalente, et prendra un nombre arbitraire d'arguments. Par exemple, pour tracer x contre y, vous pouvez exécuter la commande:

# %%
# %matplotlib inline
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %% [markdown]
# Pour chaque x, y paire d'arguments, il y a un troisième argument facultatif qui est la chaîne de format qui indique la couleur et le type de ligne du tracé. Les lettres et les symboles de la chaîne de format sont de MATLAB, et vous concaténez une chaîne de couleur avec une chaîne de style de ligne. La chaîne de format par défaut est 'b-', qui est une ligne bleue pleine. Par exemple, pour tracer le dessus avec des cercles rouges, vous pouvez faire :

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# Voir la plot() documentation pour une liste complète des styles de ligne et chaînes de format. La commande axis() dans l'exemple ci - dessus prend une liste de [xmin, xmax, ymin, ymax] et précise la fenêtre des axes.
#
# Si matplotlib était limité à travailler avec des listes, il serait assez inutile pour le traitement numérique. Généralement, vous allez utiliser numpy tableaux. En fait, toutes les séquences sont converties en matrices numpy en interne. L'exemple ci-dessous illustre un traçage de plusieurs lignes avec différents styles de format dans une commande à l'aide de tableaux.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Temps échantillonné à des intervalles de 200 ms
t = np.arange(0., 5., 0.2)

# Tirets rouges, carrés bleus et triangles verts
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# # Contrôle de propriétés de ligne
#
# Les lignes ont de nombreux attributs que vous pouvez définir: linewidth, dash style, antialiased, etc. Voir : matplotlib.lines.Line2D. Il existe plusieurs façons de définir les propriétés de ligne
#
#     Utiliser le mot-clé args:

# %%
plt.plot(x, y, linewidth=2.0)

# %% [markdown]
#     Utilisez les méthodes d'un setter Line2D instance. plot retourne une liste de Line2D objets; par exemple, line1, line2 = plot(x1, y1, x2, y2) . Dans le code ci - dessous , nous allons supposer que nous avons une seule ligne de sorte que la liste renvoyée est de longueur 1. Nous utilisons tuple déballage avec la line, pour obtenir le premier élément de cette liste:

# %%
line, = plt.plot(x, y, '-')
line.set_antialiased(False) # Désactive : antialising

# %% [markdown]
#     Utilisez le setp() commande. L'exemple ci-dessous utilise une commande MATLAB-style pour définir plusieurs propriétés sur une liste de lignes. setp fonctionne de manière transparente avec une liste d'objets ou d' un objet unique. Vous pouvez soit utiliser des arguments de mots clés python, soit des paires string / value de type MATLAB:

# %%
lines = plt.plot(x1, y1, x2, y2)
# Utiliser le mot-clé args
plt.setp(lines, color='r', linewidth=2.0)
# ou MATLAB style paires de valeur de chaîne
plt.setp(lines, 'color', 'r', 'linewidth', 2.0)

# %% [markdown]
# Voici les disponibles Line2D propriétés.
#
#     Propriété				Type de valeur
#     alpha					flotte
#     animé					[Vrai | Faux]
#     Antialiasée ou aa		[Vrai | Faux]
#     Clip_box				Une instance matplotlib.transform.Bbox
#     Clip_on					[Vrai | Faux]
#     Clip_path				Une instance Path et une instance Transform, un Patch
#     Couleur ou c			Toute couleur matplotlib
#     Contient				La fonction de test de succès
#     Dash_capstyle			[ 'butt' | 'round' | 'projecting' ]
#     Dash_joinstyle			[ 'miter' | 'round' | 'bevel' ]
#     Tirets					Séquence d'en-têtes d'encre / d'encre en points
#     données					(Np.array xdata, np.array ydata)
#     figure					Une occurrence matplotlib.figure.Figure
#     étiquette				N'importe quelle chaîne
#     Linestyle ou ls			[ '-' | '--' | '-.' | ':' | 'steps' | ...]
#     Linewidth ou lw			Valeur flottante en points
#     Lod						[Vrai | Faux]
#     marqueur				[ '+' | ',' | '.' | '1' | '2' | '3' | '4' ]
#     Markeredgecolor ou mec	Toute couleur matplotlib
#     Markeredgewidth ou mew	Valeur flottante en points
#     Markerfacecolor ou mfc	Toute couleur matplotlib
#     Markersize ou ms		flotte
#     Markevery				[Aucun | Entier | (Startind, stride)]
#     cueilleur				Utilisé dans la sélection de ligne interactive
#     Pickradius				Le rayon de sélection de ligne
#     Solid_capstyle			[ 'butt' | 'round' | 'projecting' ]
#     Solid_joinstyle			[ 'miter' | 'round' | 'bevel' ]
#     transformer				Un matplotlib.transforms.Transform instance
#     visible					[Vrai | Faux]
#     Xdata					Np.array
#     Ydata					Np.array
#     Zorder					n'importe quel chiffre
#
# Pour obtenir une liste des propriétés de ligne paramétrables, appelez le setp() fonction avec une ou plusieurs lignes comme argument

# %%
lines = plt.plot([1, 2, 3])

plt.setp(lines)
alpha: float
animated: [True | False]
antialiased or aa: [True | False]
    snip
# Out:
#   File "<ipython-input-4-cbbe1984f5f3>", line 4
#     alpha: float
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Travailler avec plusieurs figures et axes
#
# MATLAB et pyplot , ont le concept de la figure actuelle et les axes actuels. Toutes les commandes de traçage s'appliquent aux axes actuels. La fonction gca() renvoie les axes actuels, et gcf() renvoie le chiffre actuel. Normalement, vous n'avez pas à vous inquiéter à ce sujet, car il est tout pris en charge dans les coulisses. Ci-dessous un script pour créer deux sous-tracés.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %% [markdown]
# La commande figure() ici est facultative car la figure(1) sera créé par défaut, tout comme une subplot(111) sera créé par défaut si vous ne spécifiez pas manuellement les axes. La commande subplot() spécifie numrows, numcols, fignum où fignum varie de 1 à numrows*numcols . Les virgules dans la commande subplot  sont facultatifs si numrows*numcols<10 . Donc subplot(211) est identique à subplot(2, 1, 1) . Vous pouvez créer un nombre arbitraire de sous-tracés et d'axes. Si vous voulez placer un axes manuellement, à savoir, non pas sur une grille rectangulaire, utilisez les axes() de commande, ce qui vous permet de spécifier l'emplacement comme axes([left, bottom, width, height]) où toutes les valeurs sont en fractionnaire (0 à 1). Voir le code pylab_examples exemple: axes_demo.py pour un exemple de placer manuellement les axes et le code pylab_examples exemple: subplots_demo.py pour un exemple avec beaucoup de sous - parcelles.
#
# Vous pouvez créer plusieurs chiffres à l'aide de multiples figure() appelle à un nombre croissant de figure. Bien sûr, chaque figure peut contenir autant d'axes et de sous-traits que votre cœur le désire:

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # première figure
plt.subplot(211)             # La première sous-parcelle de la première figure
plt.plot([1, 2, 3])
plt.subplot(212)             # La deuxième sous-trame de la première figure
plt.plot([4, 5, 6])


plt.figure(2)                # seconde figure
plt.plot([4, 5, 6])          # crée un subplot(111) par défaut

plt.figure(1)                # Figure 1 courant; Sous-trame (212) encore en cours
plt.subplot(211)             # transformer subplot(211) de la figure 1 en cours
plt.title('Easy as 1, 2, 3') # subplot 211 titre

# %% [markdown]
# Vous pouvez effacer le chiffre actuel avec clf() et les axes actuels avec cla() . Si vous trouvez ennuyeux que les états (en particulier l'image, la figure et les axes actuels) soient maintenus pour vous dans les coulisses, ne désespérez pas: c'est juste un wrapper mince état autour d'une API orientée objet, que vous pouvez utiliser à la place.
#
# Si vous faites beaucoup de chiffres, vous devez être au courant d'une chose: la mémoire requise pour un chiffre n'est complètement libéré que si le chiffre est explicitement fermée avec close() . Suppression de toutes les références à la figure, et/ou en utilisant le gestionnaire de fenêtres pour tuer la fenêtre dans laquelle le chiffre apparaît sur l'écran, ne suffit pas, parce pyplot maintient des références internes jusqu'à ce que close() soit appelée.
#
# # Travailler avec le texte
#
# Le commande text() peut être utilisée pour ajouter du texte dans un emplacement arbitraire et le xlabel() , ylabel() et title() sont utilisés pour ajouter du texte aux endroits indiqués.

# %%
import numpy as np
import matplotlib.pyplot as plt

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# histogramme de la data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# Toutes les commandes text() renvoient un matplotlib.text.Text. Tout comme avec les lignes ci - dessus, vous pouvez personnaliser les propriétés en passant des arguments dans les fonctions de texte ou en utilisant setp() :

# %%
t = plt.xlabel('my data', fontsize=14, color='red')

# %% [markdown]
# ## Utilisation d' expressions mathématiques dans le texte
#
# Matplotlib accepte les expressions d'équation TeX dans n'importe quelle expression de texte. Par exemple pour écrire une expression dans le titre, vous pouvez écrire une expression TeX entourée de signes de dollar:

# %%
plt.title(r'$\sigma_i=15$')

# %% [markdown]
# Le r précédant la chaîne de titre est important - cela signifie que la chaîne est une chaîne brute et de ne pas traiter les antislashs comme échappe python. matplotlib a un analyseur intégré d'expression de TeX et le moteur de mise en page, et les navires de ses propres polices de mathématiques - pour détails , voir écriture d' expressions mathématiques . Ainsi, vous pouvez utiliser du texte mathématique entre plates-formes sans avoir besoin d'une installation TeX. Pour ceux qui ont LaTeX et dvipng installés, vous pouvez également utiliser LaTeX pour formater votre texte et d' incorporer directement la sortie dans vos chiffres d'affichage ou postscript sauvé - voir le rendu de texte avec LaTeX .
#
# ## Annotation texte
#
# Les utilisations de la base de la commande text() ci - dessus permet de placer du texte à une position arbitraire sur les axes. Une utilisation courante pour le texte est d'annoter une caractéristique de l'intrigue, et la méthode annotate() fournit des fonctionnalités d'aide pour faire des annotations facile. Dans une annotation, il y a deux points à considérer: l'emplacement étant annotée représentés par l'argument xy et l'emplacement du texte xytext . Ces deux arguments sont (x,y) tuples.

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

plt.ylim(-2,2)
plt.show()

# %% [markdown]
# Dans cet exemple de base, à la fois le xy (pointe de la flèche) et xytext emplacements (emplacement de texte) sont en coordonnées de données. Il existe une variété d'autres systèmes de coordonnées , on peut choisir - voir Annotation texte et Annotation Haches pour plus de détails. D' autres exemples peuvent être trouvés dans le code pylab_examples exemple: annotation_demo.py .
#
# # Logarithmiques et autre axe non linéaire
#
# matplotlib.pyplot supporte non seulement les échelles des axes linéaires, mais aussi des échelles logarithmiques et logit. Ceci est communément utilisé si les données couvrent de nombreux ordres de grandeur. Changer l'échelle d'un axe est facile:
#
#     Plt.xscale ('log')
#
# Un exemple de quatre parcelles avec les mêmes données et différentes échelles pour l'axe y est illustré ci-dessous.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Faire quelques données dans l'intervalle ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot avec différentes échelles d'axes
plt.figure(1)

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)


# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)


# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.05)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)

plt.show()

# %% [markdown]
# # Source :
#
# http://matplotlib.org/users/pyplot_tutorial.html
